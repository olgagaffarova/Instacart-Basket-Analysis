# %% [markdown]
# # 01 Importing Libraries

# %%
import pandas as pd
import numpy as np
import os

# %% [markdown]
# # 02 Importing Data

# %%
path = r'/Users/woodoooo/Desktop/Instacart Basket Analysis'

# %%
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data' , 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
df_ords_prods_merge = df_ords_prods_merge[:1000000]

# %%
df_ords_prods_merge.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   order_id                1000000 non-null  int64
#  1   user_id                 1000000 non-null  int64
#  2   order_number            1000000 non-null  int64
#  3   order_day_of_week       1000000 non-null  int64
#  4   order_hour_of_day       1000000 non-null  int64
#  5   days_since_prior_order  936384 non-null   float64
#  6   new_customer            1000000 non-null  bool
#  7   product_id              1000000 non-null  int64
#  8   add_to_cart_order       1000000 non-null  int64
#  9   reordered               1000000 non-null  int64
#  10  product_name            1000000 non-null  object
#  11  aisle_id                1000000 non-null  int64
#  12  department_id           1000000 non-null  int64
# ...

# %%
# Change data types for multiple columns in one go
df_ords_prods_merge = df_ords_prods_merge.astype({
    'order_id': 'int32',
    'user_id': 'int32',
    'order_number': 'int8',
    'order_day_of_week': 'int8',
    'order_hour_of_day': 'int8',
    'product_id': 'int32',
    'add_to_cart_order': 'int32',
    'reordered': 'int8',
    'days_since_prior_order': 'float32',
    'aisle_id': 'int32',
    'department_id': 'int32',
    'prices': 'float32'
    })

# %% [markdown]
# # 03 Grouping products (sample)

# %% [markdown]
# If the value within the “prices” column within the given row is less than or equal to 5, then return the string “Low-range product.”
#
# Or else, if the value within the “prices” column within the given row is greater than 5 and less than or equal to 15, then return the string “Mid-range product.”
#
# Or else, if the value of the “prices” column within the given row is greater than 15, then return the string “High-range product.”
#
# Or else, return the string “Not enough data.”

# %%
# Grouping products

def price_label(row):
    if row['prices'] <=5:
        return 'Low-range product'
    elif (row['prices']) >5 and (row['prices']) <=15:
        return 'Middle-range product'
    elif row['prices'] >15:
        return 'High-range product'
    else: return 'Not enough data'

# %%
df_ords_prods_merge['price_range'] = df_ords_prods_merge.apply(price_label, axis=1)

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
df_ords_prods_merge.shape
# Out:
# (1000000, 16)

# %%
df_ords_prods_merge['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Middle-range product    673340
# Low-range product       314392
# High-range product       12268
# Name: count, dtype: int64

# %%
df_ords_prods_merge['prices'].max()
# Out:
# 25.0

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] > 15, 'price_range'] = 'High-range'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['prices']<=15) &
(df_ords_prods_merge['prices'] >5), 'price_range'] = 'Mid-range'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] <5, 'price_range'] = Low-range'

# %%
df_ords_prods_merge['price_range'].value_counts(dropna = False)
# Out:
# price_range
# Mid-range            673340
# Low-range            307024
# High-range            12268
# Low-range product      7368
# Name: count, dtype: int64

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
df_ords_prods_merge.drop(['price_range_loc'], axis = 1, inplace = True)

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %% [markdown]
# # 04 Grouping products (entire database)

# %%
df_ords_prods_merge = pd.read_pickle(os.path.join(path, '02 Data' , 'Prepared Data', 'ords_prods_merge.pkl'))

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 15)

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] > 15, 'price_range_loc'] = 'High-range'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['prices'] <=15) & (df_ords_prods_merge['prices'] >5) , 'price_range_loc'] = 'Mid-range'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] <=5, 'price_range_loc'] = 'Low-range'

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 16)

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
df_ords_prods_merge['price_range_loc'].value_counts(dropna = False)
# Out:
# price_range_loc
# Mid-range     21865987
# Low-range     10126321
# High-range      412551
# Name: count, dtype: int64

# %% [markdown]
# # 05 If-Statements with For-Loops

# %%
print('my age is 30')
# Out:
# my age is 30

# %%
print('my age is 31')
# Out:
# my age is 31

# %%
print('my age is 32')
# Out:
# my age is 32

# %%
print('my age is 33')
# Out:
# my age is 33

# %%
for x in range (30,45):
    print('my age is %d' % (x))
# Out:
# my age is 30
# my age is 31
# my age is 32
# my age is 33
# my age is 34
# my age is 35
# my age is 36
# my age is 37
# my age is 38
# my age is 39
# my age is 40
# my age is 41
# my age is 42
# my age is 43
# my age is 44

# %%
for age in range (25,30):
    print(f'I am {age} years old')
# Out:
# I am 25 years old
# I am 26 years old
# I am 27 years old
# I am 28 years old
# I am 29 years old

# %%
name = "Olga"
age = 25
print(f'My name is {name} and I am {age} years old')
# Out:
# My name is Olga and I am 25 years old

# %% [markdown]
# # 06 Create a new column in your ords_prods_merge dataframe that summarizes how busy each day of the week is.

# %%
df_ords_prods_merge['order_day_of_week'].value_counts(dropna = False)
# Out:
# order_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []

for value in df_ords_prods_merge["order_day_of_week"]:
  if value == 0:
    result.append("Busiest day")
  elif value == 4:
    result.append("Least busy")
  else:
    result.append("Regularly busy")

# %%
result
# Out:
# ['Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Least busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
#  'Regularly busy',
# ...

# %%
df_ords_prods_merge['Busiest day'] = result

# %%
df_ords_prods_merge.head()
# Out:
#    order_id  user_id  order_number  order_day_of_week  order_hour_of_day  \
# 0   2539329        1             1                  2                  8
# 1   2539329        1             1                  2                  8
# 2   2539329        1             1                  2                  8
# 3   2539329        1             1                  2                  8
# 4   2539329        1             1                  2                  8
#
#    days_since_prior_order  new_customer  product_id  add_to_cart_order  \
# 0                     NaN          True         196                  1
# 1                     NaN          True       14084                  2
# 2                     NaN          True       12427                  3
# 3                     NaN          True       26088                  4
# 4                     NaN          True       26405                  5
#
#    reordered                             product_name  aisle_id  \
# ...

# %%
df_ords_prods_merge['Busiest day'].value_counts(dropna = False)
# Out:
# Busiest day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %% [markdown]
# # 07 Exporting Data

# %%
# Export data to pkl
df_ords_prods_merge.to_pickle(os.path.join(path, '02 Data','Prepared Data', '4.7_ords_prods_merge_Part 1.pkl'))
